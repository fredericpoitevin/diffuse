# %% [markdown]
# # Data
#
# originally found at `poitevin .at. smbcopy.slac.stanford.edu:/data/demirci`
#
# ## `dataprocess`
# (m6a July 2014) [info][1]
#
# ## `05_27_15`
# (pseudoU sisomycin May 2015) [info][1]
#
# ## `06_26_15 `
# (Ricci sisomycin June 2015) [info][1]
#
# Datasets are A5, B1, C1, D1:  Uploaded
#
# ## `07_16_15`
# Uploading
#
# ## `07_18_15`
# Uploading
#
# ## `03_16_16`
# Uploading
#
# ## `07_19_16_AG`
# (aminoglycosides July 2016)
#
# ### A3+
#
#  1 | 2 | 3 | 4
# --- | --- | --- | ---
# ![A3_1_reduce.gif](./gifs/A3_1_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8LVMtSExtdHAzd3c) | ![A3_2_reduce.gif](./gifs/A3_2_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8Ql9Xc21yc1V0b2M) | ![A3_3_reduce.gif](./gifs/A3_3_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8Tkt6SzU3NjFXVzA) | ![A3_4_reduce.gif](./gifs/A3_4_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8ZW1URUhVbHNzcVU)
#
# ### A7+
#
#  1 | 2 | 3 | 4
# --- | --- | --- | ---
# ![A7_1_reduce.gif](./gifs/A7_1_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8b19rVDQwQ2RvZGs) | ![A7_2_reduce.gif](./gifs/A7_2_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8VE9QN0hHYjlDOUE) | ![A7_3_reduce.gif](./gifs/A7_3_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8MjBMSXBLSGJ6TVE) | ![A7_4_reduce.gif](./gifs/A7_4_reduce.gif) [full](https://drive.google.com/open?id=0BzbPTk3pdrM8cmctQTE5dXBCM2M)
#
# ###  B5+
#
# (no gif yet)
#
# ### C3+
#
# (no gif yet)
#
# ### A1+ (Cas411_A1+)
#
# (no gif yet)
#
# ### D4+
#
# ### D8+
#
# ### E7+
#
# ### F7+
#
# ### G7+
#
# ### H2+
#
# ### H7+
#
# ### I1+
#
# ### I4
#
# ### I5+
#
# ### I6
#
# ### J5+
#
# ### L1+
#
# ### L4+
#
#
#
# ## `12_04_16_AG`
# (aminoglycosides December 2016)
# EMPTY ?
#
# ## `12_19_16_AG_Gentamicin`
# (aminoglycosides December 2016)
# J7:1-5
# K4:1-5
# K5:1-2
# K5B:1-4
#
#
#
#
# [1]: https://docs.google.com/spreadsheets/d/1IrIsiR9P6u-ETemXnp82NSMGmmAN7EoqltV4IRQAv2A/edit#gid=1450704779

# %% [markdown]
# Analysis:
# Try this multi-crystal analysis tool PaNDDA
# https://www.nature.com/articles/ncomms15123
# Now part of ccp4. 3 tools available: pandda.analyse  pandda.export   pandda.inspect
# Run with --help to get info on how to use
#
# Misc:
# https://en.wikipedia.org/wiki/Aminoglycoside
